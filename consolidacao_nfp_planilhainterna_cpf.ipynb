# %% [markdown]
# <a href="https://colab.research.google.com/github/vitu-p/creating_data_base_nfp/blob/main/consolidacao_nfp_planilhainterna_cpf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openpyxl -q

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-caa8ee86-c496-47c7-8b39-1eb7e1b381a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-caa8ee86-c496-47c7-8b39-1eb7e1b381a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import zipfile
import os

nome_zip = list(uploaded.keys())[0]

with zipfile.ZipFile(nome_zip, 'r') as z:
    z.extractall("pasta_dados")

arquivos = []
for root, dirs, files_list in os.walk("pasta_dados"):
    for file in files_list:
        if file.endswith(".xlsx") and not file.startswith("~$"):
            arquivos.append(os.path.join(root, file))

print(f"{len(arquivos)} arquivo(s) encontrado(s):")
for a in arquivos:
    print(" -", a)

# %%
dfs = []
erros = []

for caminho in arquivos:
    try:
        df = pd.read_excel(caminho, sheet_name="CPF", engine="openpyxl")
        df["arquivo_origem"] = os.path.basename(caminho)
        dfs.append(df)
        print(f"✅ {os.path.basename(caminho)} — {len(df):,} linhas")
    except Exception as e:
        erros.append(caminho)
        print(f"❌ Erro em {os.path.basename(caminho)}: {e}")

consolidado = pd.concat(dfs, ignore_index=True)
print(f"\nTotal consolidado: {len(consolidado):,} linhas")

consolidado.to_excel("consolidado_cpf.xlsx", index=False)
print("Arquivo salvo!")

# %%
from google.colab import files
files.download("consolidado_cpf.xlsx")
